# %%
# Let's create a DataFrame from the provided CSV content directly
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV string
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')

# Plotting function
def plot_statistics(data):
    # Create subplots
    fig, axs = plt.subplots(3, 3, figsize=(15, 15))
    fig.suptitle('Statistics over Different Link Probabilities and Link Sizes')

    # Plot total GPU vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[0, 0].plot(subset['link prob'], subset['tot_GPU'], label=f'Link BW {link_bw}')
    axs[0, 0].set_title('Total GPU vs Link Probability')
    axs[0, 0].set_xlabel('Link Probability')
    axs[0, 0].set_ylabel('Total GPU')
    axs[0, 0].legend()

    # Plot allocated GPU vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[0, 1].plot(subset['link prob'], subset['allocated_GPU'], label=f'Link BW {link_bw}')
    axs[0, 1].set_title('Allocated GPU vs Link Probability')
    axs[0, 1].set_xlabel('Link Probability')
    axs[0, 1].set_ylabel('Allocated GPU')
    axs[0, 1].legend()

    # Plot GPU usage percentage vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[0, 2].plot(subset['link prob'], subset['GPU'], label=f'Link BW {link_bw}')
    axs[0, 2].set_title('GPU Usage % vs Link Probability')
    axs[0, 2].set_xlabel('Link Probability')
    axs[0, 2].set_ylabel('GPU Usage %')
    axs[0, 2].legend()

    # Plot total GPU vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[1, 0].plot(subset['link prob'], subset['tot_gpu'], label=f'Link BW {link_bw}')
    axs[1, 0].set_title('Total GPU vs Link Probability')
    axs[1, 0].set_xlabel('Link Probability')
    axs[1, 0].set_ylabel('Total GPU')
    axs[1, 0].legend()

    # Plot allocated GPU vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[1, 1].plot(subset['link prob'], subset['allocated_gpu'], label=f'Link BW {link_bw}')
    axs[1, 1].set_title('Allocated GPU vs Link Probability')
    axs[1, 1].set_xlabel('Link Probability')
    axs[1, 1].set_ylabel('Allocated GPU')
    axs[1, 1].legend()

    # Plot GPU usage percentage vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[1, 2].plot(subset['link prob'], subset['gpu'], label=f'Link BW {link_bw}')
    axs[1, 2].set_title('GPU Usage % vs Link Probability')
    axs[1, 2].set_xlabel('Link Probability')
    axs[1, 2].set_ylabel('GPU Usage %')
    axs[1, 2].legend()
—Training deep learning (DL) models in a distributedd Jobs')
    axs[2, 1].legend()

    # Plot rejected jobs vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[2, 2].plot(subset['link prob'], subset['rejected_jobs'], label=f'Link BW {link_bw}')
    axs[2, 2].set_title('Rejected Jobs vs Link Probability')
    axs[2, 2].set_xlabel('Link Probability')
    axs[2, 2].set_ylabel('Rejected Jobs')
    axs[2, 2].legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

# Plot the statistics
plot_statistics(data)

# %%
# Let's create a DataFrame from the provided CSV content directly
import pandas as pd
import matplotlib.pyplot as plt

# Read the data from the CSV file
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')

# Plotting function
def plot_statistics(data):
    # Create subplots
    fig, axs = plt.subplots(2, 2, figsize=(15, 15))
    fig.suptitle('Percentage Statistics over Different Link Probabilities and Link Sizes')

    # Plot GPU usage percentage vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[0, 0].plot(subset['link prob'], subset['GPU'], label=f'Link BW {link_bw}')
    axs[0, 0].set_title('GPU Usage % vs Link Probability')
    axs[0, 0].set_xlabel('Link Probability')
    axs[0, 0].set_ylabel('GPU Usage %')
    axs[0, 0].legend()

    # Plot GPU usage percentage vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[0, 1].plot(subset['link prob'], subset['gpu'], label=f'Link BW {link_bw}')
    axs[0, 1].set_title('GPU Usage % vs Link Probability')
    axs[0, 1].set_xlabel('Link Probability')
    axs[0, 1].set_ylabel('GPU Usage %')
    axs[0, 1].legend()

    # Plot allocated bandwidth percentage vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[1, 0].plot(subset['link prob'], subset['allocated_bw'], label=f'Link BW {link_bw}')
    axs[1, 0].set_title('Allocated Bandwidth % vs Link Probability')
    axs[1, 0].set_xlabel('Link Probability')
    axs[1, 0].set_ylabel('Allocated Bandwidth %')
    axs[1, 0].legend()

    # Plot allocated jobs percentage vs link probability for different link sizes
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        axs[1, 1].plot(subset['link prob'], subset['allocated_jobs'], label=f'Link BW {link_bw}')
    axs[1, 1].set_title('Allocated Jobs % vs Link Probability')
    axs[1, 1].set_xlabel('Link Probability')
    axs[1, 1].set_ylabel('Allocated Jobs %')
    axs[1, 1].legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

# Plot the statistics
plot_statistics(data)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the data from the CSV file
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')

# Function to plot CDFs
def plot_cdfs(data):
    # Create subplots
    fig, axs = plt.subplots(2, 2, figsize=(15, 15))
    fig.suptitle('CDF of Percentage Statistics over Different Link Probabilities and Link Sizes')

    # Function to calculate the CDF
    def compute_cdf(data):
        sorted_data = np.sort(data)
        yvals = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
        return sorted_data, yvals

    # Plot CDF for GPU usage percentage
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        x, y = compute_cdf(subset['GPU'])
        axs[0, 0].plot(x, y, label=f'Link BW {link_bw}')
    axs[0, 0].set_title('CDF of GPU Usage %')
    axs[0, 0].set_xlabel('GPU Usage %')
    axs[0, 0].set_ylabel('CDF')
    axs[0, 0].legend()

    # Plot CDF for GPU usage percentage
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        x, y = compute_cdf(subset['gpu'])
        axs[0, 1].plot(x, y, label=f'Link BW {link_bw}')
    axs[0, 1].set_title('CDF of GPU Usage %')
    axs[0, 1].set_xlabel('GPU Usage %')
    axs[0, 1].set_ylabel('CDF')
    axs[0, 1].legend()

    # Plot CDF for allocated bandwidth percentage
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        x, y = compute_cdf(subset['allocated_bw'])
        axs[1, 0].plot(x, y, label=f'Link BW {link_bw}')
    axs[1, 0].set_title('CDF of Allocated Bandwidth %')
    axs[1, 0].set_xlabel('Allocated Bandwidth %')
    axs[1, 0].set_ylabel('CDF')
    axs[1, 0].legend()

    # Plot CDF for allocated jobs percentage
    for link_bw in data['link_bw'].unique():
        subset = data[data['link_bw'] == link_bw]
        x, y = compute_cdf(subset['allocated_jobs'])
        axs[1, 1].plot(x, y, label=f'Link BW {link_bw}')
    axs[1, 1].set_title('CDF of Allocated Jobs %')
    axs[1, 1].set_xlabel('Allocated Jobs %')
    axs[1, 1].set_ylabel('CDF')
    axs[1, 1].legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

# Plot the CDFs
plot_cdfs(data)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# Provided CSV content
csv_content = """utility,num_nodes,link prob,link_bw,tot_GPU,allocated_GPU,GPU,tot_gpu,allocated_gpu,gpu,allocated_bw,allocated_jobs,rejected_jobs
Utility.SGF,100,0.5,1000,960000,38400,4.0,80000,2500,3.125,0,6,29"""

# Create DataFrame from CSV content
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')



# Plotting function for comparing utility function statistics
def plot_comparison_statistics(data):
    utility_functions = data['utility'].unique()
    cmap = plt.get_cmap('tab10')
    colors = [cmap(i) for i in range(len(utility_functions))]

    fig, axs = plt.subplots(2, 2, figsize=(15, 15))
    fig.suptitle('Comparison of Percentage Statistics for Different Utility Functions')

    # Plot GPU usage percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        for link_bw in subset['link_bw'].unique():
            link_subset = subset[subset['link_bw'] == link_bw]
            axs[0, 0].plot(link_subset['link prob'], link_subset['GPU'], label=f'{utility} - Link BW {link_bw}', color=colors[idx])
    axs[0, 0].set_title('GPU Usage % vs Link Probability')
    axs[0, 0].set_xlabel('Link Probability')
    axs[0, 0].set_ylabel('GPU Usage %')
    axs[0, 0].legend()

    # Plot GPU usage percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        for link_bw in subset['link_bw'].unique():
            link_subset = subset[subset['link_bw'] == link_bw]
            axs[0, 1].plot(link_subset['link prob'], link_subset['gpu'], label=f'{utility} - Link BW {link_bw}', color=colors[idx])
    axs[0, 1].set_title('GPU Usage % vs Link Probability')
    axs[0, 1].set_xlabel('Link Probability')
    axs[0, 1].set_ylabel('GPU Usage %')
    axs[0, 1].legend()

    # Plot allocated bandwidth percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        for link_bw in subset['link_bw'].unique():
            link_subset = subset[subset['link_bw'] == link_bw]
            axs[1, 0].plot(link_subset['link prob'], link_subset['allocated_bw'], label=f'{utility} - Link BW {link_bw}', color=colors[idx])
    axs[1, 0].set_title('Allocated Bandwidth % vs Link Probability')
    axs[1, 0].set_xlabel('Link Probability')
    axs[1, 0].set_ylabel('Allocated Bandwidth %')
    axs[1, 0].legend()

    # Plot allocated jobs percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        for link_bw in subset['link_bw'].unique():
            link_subset = subset[subset['link_bw'] == link_bw]
            axs[1, 1].plot(link_subset['link prob'], link_subset['allocated_jobs'], label=f'{utility} - Link BW {link_bw}', color=colors[idx])
    axs[1, 1].set_title('Allocated Jobs % vs Link Probability')
    axs[1, 1].set_xlabel('Link Probability')
    axs[1, 1].set_ylabel('Allocated Jobs %')
    axs[1, 1].legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

# Plot the comparison statistics
plot_comparison_statistics(data)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')

# Plotting function for comparing utility function statistics with a selected bandwidth
def plot_comparison_statistics(data, selected_bw):
    # Filter the data by the selected bandwidth
    data = data[data['link_bw'] == selected_bw]
    utility_functions = data['utility'].unique()
    cmap = plt.get_cmap('tab10')
    colors = [cmap(i) for i in range(len(utility_functions))]

    fig, axs = plt.subplots(2, 2, figsize=(15, 15))
    fig.suptitle(f'Comparison of Percentage Statistics for Different Utility Functions at Link BW {selected_bw}')

    # Plot GPU usage percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        axs[0, 0].plot(subset['link prob'], subset['GPU'], label=f'{utility}', color=colors[idx])
    axs[0, 0].set_title('GPU Usage % vs Link Probability')
    axs[0, 0].set_xlabel('Link Probability')
    axs[0, 0].set_ylabel('GPU Usage %')
    axs[0, 0].legend()

    # Plot GPU usage percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        axs[0, 1].plot(subset['link prob'], subset['gpu'], label=f'{utility}', color=colors[idx])
    axs[0, 1].set_title('GPU Usage % vs Link Probability')
    axs[0, 1].set_xlabel('Link Probability')
    axs[0, 1].set_ylabel('GPU Usage %')
    axs[0, 1].legend()

    # Plot allocated bandwidth percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        axs[1, 0].plot(subset['link prob'], subset['allocated_bw'], label=f'{utility}', color=colors[idx])
    axs[1, 0].set_title('Allocated Bandwidth % vs Link Probability')
    axs[1, 0].set_xlabel('Link Probability')
    axs[1, 0].set_ylabel('Allocated Bandwidth %')
    axs[1, 0].legend()

    # Plot allocated jobs percentage vs link probability for different utility functions
    for idx, utility in enumerate(utility_functions):
        subset = data[data['utility'] == utility]
        axs[1, 1].plot(subset['link prob'], subset['allocated_jobs'], label=f'{utility}', color=colors[idx])
    axs[1, 1].set_title('Allocated Jobs % vs Link Probability')
    axs[1, 1].set_xlabel('Link Probability')
    axs[1, 1].set_ylabel('Allocated Jobs %')
    axs[1, 1].legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

# Example usage: Plot the comparison statistics for a specific link bandwidth
selected_bw = 4000  # Change this to the desired bandwidth value
plot_comparison_statistics(data, selected_bw)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the CSV file
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')

# Function to calculate the CDF
def compute_cdf(data):
    sorted_data = np.sort(data)
    yvals = np.arange(1, len(sorted_data) + 1) / len(sorted_data)
    return sorted_data, yvals

# Plotting function for CDF comparison
def plot_cdf_statistics(data):
    utility_functions = data['utility'].unique()
    metrics = ['GPU', 'gpu', 'allocated_bw', 'allocated_jobs']
    metric_labels = ['GPU Usage %', 'GPU Usage %', 'Allocated Bandwidth %', 'Allocated Jobs %']
    colors = plt.cm.tab10(np.linspace(0, 1, len(utility_functions)))

    fig, axs = plt.subplots(2, 2, figsize=(15, 15))
    fig.suptitle('CDF Comparison for Different Utility Functions')

    for i, metric in enumerate(metrics):
        ax = axs[i // 2, i % 2]
        for idx, utility in enumerate(utility_functions):
            subset = data[data['utility'] == utility]
            sorted_data, yvals = compute_cdf(subset[metric])
            ax.plot(sorted_data, yvals, label=f'{utility}', color=colors[idx])
        ax.set_title(f'Cumulative Distribution of {metric_labels[i]}')
        ax.set_xlabel(metric_labels[i])
        ax.set_ylabel('CDF')
        ax.legend()

    plt.tight_layout()
    plt.subplots_adjust(top=0.95)
    plt.show()

# Plot the CDF statistics
plot_cdf_statistics(data)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results1.csv')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file

# Function to plot boxplots for each metric, grouped by utility and bandwidth
def plot_combined_boxplots(data):
    metrics = ['GPU', 'gpu', 'allocated_bw', 'allocated_jobs']
    metric_labels = ['GPU Usage %', 'GPU Usage %', 'Allocated Bandwidth %', 'Allocated Jobs %']
    
    for i, metric in enumerate(metrics):
        plt.figure(figsize=(15, 10))
        plt.title(f'Boxplot of {metric_labels[i]} by Utility and Link Bandwidth')
        
        sns.boxplot(x='link_bw', y=metric, hue='utility', data=data, palette='Set3')
        
        plt.xlabel('Link Bandwidth')
        plt.ylabel(metric_labels[i])
        plt.legend(title='Utility')
        plt.show()

# Plot the combined boxplots
plot_combined_boxplots(data)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
T_forward = 0.1  # Forward propagation time (seconds)
T_back = 0.05  # Backward propagation time (seconds)
w = 10  # Number of workers
p = 5  # Number of parameter servers
S = 1e9  # Model size in bytes (1 GB)
T_update = 0.01  # Parameter update time (seconds)
delta = 0.001  # Communication overhead coefficient for workers
delta_prime = 0.002  # Communication overhead coefficient for parameter servers

# Bandwidth capacities to simulate congestion
bandwidths = np.linspace(1e7, 1e10, 100)  # From 10 MB/s to 10 GB/s

# Number of workers per parameter server
w_prime = w / p

# Function to calculate training time for a given bandwidth
def calculate_training_time(B):
    rho = B / w_prime
    data_transfer_time = 2 * S * w_prime / (p * B)
    update_time = T_update * w_prime / p
    communication_overhead = delta * w + delta_prime * p
    T = T_forward + T_back + data_transfer_time + update_time + communication_overhead
    return T

# Calculate training times for different bandwidths
training_times = [calculate_training_time(B) for B in bandwidths]

# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(bandwidths, training_times, marker='o')
plt.title('Training Time vs Network Bandwidth')
plt.xlabel('Network Bandwidth (bytes/second)')
plt.ylabel('Training Time (seconds)')
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
T_forward = 0.1  # Forward propagation time (seconds)
T_back = 0.05  # Backward propagation time (seconds)
w = 10  # Number of workers
p = 5  # Number of parameter servers
S = 1e9  # Model size in bytes (1 GB)
T_update = 0.01  # Parameter update time (seconds)
delta = 0.001  # Communication overhead coefficient for workers
delta_prime = 0.002  # Communication overhead coefficient for parameter servers

# Bandwidth capacities to simulate congestion
bandwidths = np.linspace(1e7, 1e10, 100)  # From 10 MB/s to 10 GB/s

# Number of workers per parameter server
w_prime = w / p

# Function to calculate different components of training time for a given bandwidth
def calculate_training_time_components(B):
    rho = B / w_prime
    data_transfer_time = 2 * S * w_prime / (p * B)
    update_time = T_update * w_prime / p
    communication_overhead = delta * w + delta_prime * p
    total_time = T_forward + T_back + data_transfer_time + update_time + communication_overhead
    return {
        'total': total_time,
        'forward': T_forward,
        'backward': T_back,
        'data_transfer': data_transfer_time,
        'update': update_time,
        'communication': communication_overhead
    }

# Calculate training times for different bandwidths
training_times = [calculate_training_time_components(B) for B in bandwidths]

# Extract different components
total_times = [t['total'] for t in training_times]
forward_times = [t['forward'] for t in training_times]
backward_times = [t['backward'] for t in training_times]
data_transfer_times = [t['data_transfer'] for t in training_times]
update_times = [t['update'] for t in training_times]
communication_times = [t['communication'] for t in training_times]

# Plotting the results
plt.figure(figsize=(12, 8))

# Total training time plot
plt.subplot(2, 1, 1)
plt.plot(bandwidths, total_times, marker='o', label='Total Training Time')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Network Bandwidth (bytes/second)')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs Network Bandwidth')
plt.grid(True)
plt.legend()

# Components of training time plot
plt.subplot(2, 1, 2)
plt.plot(bandwidths, forward_times, label='Forward Propagation')
plt.plot(bandwidths, backward_times, label='Backward Propagation')
plt.plot(bandwidths, data_transfer_times, label='Data Transfer')
plt.plot(bandwidths, update_times, label='Parameter Update')
plt.plot(bandwidths, communication_times, label='Communication Overhead')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Network Bandwidth (bytes/second)')
plt.ylabel('Time (seconds)')
plt.title('Components of Training Time vs Network Bandwidth')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
T_forward = 0.1  # Forward propagation time (seconds)
T_back = 0.05  # Backward propagation time (seconds)
w = 10  # Number of workers
p = 5  # Number of parameter servers
S = 1e9  # Model size in bytes (1 GB)
T_update = 0.01  # Parameter update time (seconds)
delta = 0.001  # Communication overhead coefficient for workers
delta_prime = 0.002  # Communication overhead coefficient for parameter servers

# Bandwidth capacities to simulate congestion (selecting fewer points for clarity in bar plot)
bandwidths = np.array([1e7, 1e8, 1e9, 1e10])  # From 10 MB/s to 10 GB/s

# Number of workers per parameter server
w_prime = w / p

# Function to calculate different components of training time for a given bandwidth
def calculate_training_time_components(B):
    rho = B / w_prime
    data_transfer_time = 2 * S * w_prime / (p * B)
    update_time = T_update * w_prime / p
    communication_overhead = delta * w + delta_prime * p
    total_time = T_forward + T_back + data_transfer_time + update_time + communication_overhead
    return {
        'total': total_time,
        'forward': T_forward,
        'backward': T_back,
        'data_transfer': data_transfer_time,
        'update': update_time,
        'communication': communication_overhead
    }

# Calculate training times for different bandwidths
training_times = [calculate_training_time_components(B) for B in bandwidths]

# Extract different components
total_times = [t['total'] for t in training_times]
forward_times = [t['forward'] for t in training_times]
backward_times = [t['backward'] for t in training_times]
data_transfer_times = [t['data_transfer'] for t in training_times]
update_times = [t['update'] for t in training_times]
communication_times = [t['communication'] for t in training_times]

# Plotting the results
plt.figure(figsize=(12, 12))

# Total training time plot
plt.subplot(3, 1, 1)
plt.plot(bandwidths, total_times, marker='o', label='Total Training Time')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Network Bandwidth (bytes/second)')
plt.ylabel('Training Time (seconds)')
plt.title('Training Time vs Network Bandwidth')
plt.grid(True)
plt.legend()

# Components of training time plot
plt.subplot(3, 1, 2)
plt.plot(bandwidths, forward_times, label='Forward Propagation')
plt.plot(bandwidths, backward_times, label='Backward Propagation')
plt.plot(bandwidths, data_transfer_times, label='Data Transfer')
plt.plot(bandwidths, update_times, label='Parameter Update')
plt.plot(bandwidths, communication_times, label='Communication Overhead')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Network Bandwidth (bytes/second)')
plt.ylabel('Time (seconds)')
plt.title('Components of Training Time vs Network Bandwidth')
plt.grid(True)
plt.legend()

# Bar plot for communication times
plt.subplot(3, 1, 3)
bar_width = 0.35
indices = np.arange(len(bandwidths))

plt.bar(indices, data_transfer_times, bar_width, label='Data Transfer Time', color='b')
plt.bar(indices + bar_width, communication_times, bar_width, label='Communication Overhead', color='r')
plt.xticks(indices + bar_width / 2, [f'{b:.0e}' for b in bandwidths])
plt.xlabel('Network Bandwidth (bytes/second)')
plt.ylabel('Time (seconds)')
plt.title('Network Communication Time vs Network Bandwidth')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for ResNet-269 training
T_forward = 0.5  # Forward propagation time (seconds) - estimated for ResNet-269
T_back = 0.25  # Backward propagation time (seconds) - estimated for ResNet-269
w = 10  # Number of workers
p = 5  # Number of parameter servers
S = 1.5e9  # Model size in bytes (1.5 GB)
T_update = 0.05  # Parameter update time (seconds) - estimated for ResNet-269
delta = 0.001  # Communication overhead coefficient for workers
delta_prime = 0.002  # Communication overhead coefficient for parameter servers

# Bandwidth capacities to simulate congestion (selecting fewer points for clarity in bar plot)
bandwidths = np.array([100, 1000, 10000])  # From 100 Mbps to 10,000 Mbps

# Convert bandwidths from Mbps to bytes/second
bandwidths_bytes_per_sec = bandwidths * 1e6 / 8

# Number of workers per parameter server
w_prime = w / p

# Function to calculate different components of training time for a given bandwidth
def calculate_training_time_components(B):
    rho = B / w_prime
    gradient_size = S / p  # Each parameter server handles a fraction of the model
    data_transfer_time = 2 * gradient_size * w_prime / (p * B)
    update_time = T_update * w_prime / p
    communication_overhead = delta * w + delta_prime * p
    total_time = T_forward + T_back + data_transfer_time + update_time + communication_overhead
    return {
        'total': total_time,
        'training': T_forward + T_back,
        'data_transfer': data_transfer_time,
        'update': update_time,
        'communication': communication_overhead
    }

# Calculate training times for different bandwidths
training_times = [calculate_training_time_components(B) for B in bandwidths_bytes_per_sec]

# Extract different components
total_times = [t['total'] for t in training_times]
training_times_merged = [t['training'] for t in training_times]
data_transfer_times = [t['data_transfer'] for t in training_times]
update_times = [t['update'] for t in training_times]
communication_times = [t['communication'] for t in training_times]

# Plotting the results
plt.figure(figsize=(10, 6))

# Stacked bar plot for all components of training time (horizontal bars)
indices = np.arange(len(bandwidths))
bar_height = 0.5

plt.barh(indices, training_times_merged, bar_height, label='Training Time')
plt.barh(indices, data_transfer_times, bar_height, left=training_times_merged, label='Data Transfer')
plt.barh(indices, update_times, bar_height, left=np.array(training_times_merged) + np.array(data_transfer_times), label='Parameter Update')
plt.barh(indices, communication_times, bar_height, left=np.array(training_times_merged) + np.array(data_transfer_times) + np.array(update_times), label='Communication Overhead')

plt.yticks(indices, [f'{b} Mbps' for b in bandwidths])
plt.ylabel('Network Bandwidth (Mbps)')
plt.xlabel('Training Time (seconds)')
# plt.title('Components of Training Time vs Network Bandwidth for ResNet-269')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# Parameters for ResNet-269 training
T_forward = 0.75  # Forward propagation time (seconds) - estimated for ResNet-269
T_back = 0.25  # Backward propagation time (seconds) - estimated for ResNet-269
w = 10  # Number of workers
p = 5  # Number of parameter servers
S = 1.5e9  # Model size in bytes (1.5 GB)
T_update = 0.05  # Parameter update time (seconds) - estimated for ResNet-269
delta = 0.001  # Communication overhead coefficient for workers
delta_prime = 0.002  # Communication overhead coefficient for parameter servers

# Bandwidth capacities to simulate congestion (selecting fewer points for clarity in bar plot)
bandwidths = np.array([100, 1000, 10000])  # From 100 Mbps to 10,000 Mbps

# Convert bandwidths from Mbps to bytes/second
bandwidths_bytes_per_sec = bandwidths * 1e6 / 8

# Number of workers per parameter server
w_prime = w / p

# Function to calculate different components of training time for a given bandwidth
def calculate_training_time_components(B):
    rho = B / w_prime
    data_transfer_time = 2 * S * w_prime / (p * B)
    update_time = T_update * w_prime / p
    communication_overhead = delta * w + delta_prime * p
    total_time = T_forward + T_back + data_transfer_time + update_time + communication_overhead
    return {
        'total': total_time,
        'training': T_forward + T_back,
        'data_transfer': data_transfer_time,
        'update': update_time,
        'communication': communication_overhead
    }

# Calculate training times for different bandwidths
training_times = [calculate_training_time_components(B) for B in bandwidths_bytes_per_sec]

# Extract different components
total_times = [t['total'] for t in training_times]
training_times_merged = [t['training'] for t in training_times]
data_transfer_times = [t['data_transfer'] for t in training_times]
update_times = [t['update'] for t in training_times]
communication_times = [t['communication'] for t in training_times]

# Create a figure with a broken y-axis
fig = plt.figure(figsize=(8, 5))
gs = gridspec.GridSpec(2, 1, height_ratios=[1, 3])

# Top plot
ax0 = plt.subplot(gs[0])
ax0.bar(indices, training_times_merged, bar_width, label='Training Time')
ax0.bar(indices, data_transfer_times, bar_width, bottom=training_times_merged, label='Data Transfer')
ax0.bar(indices, update_times, bar_width, bottom=np.array(training_times_merged) + np.array(data_transfer_times), label='Parameter Update')
ax0.bar(indices, communication_times, bar_width, bottom=np.array(training_times_merged) + np.array(data_transfer_times) + np.array(update_times), label='Communication Overhead')
ax0.set_ylim(70, 100)  # Adjust the ylim for the top plot
ax0.set_xticks([])  # Hide x-axis ticks on the top plot

# Bottom plot
ax1 = plt.subplot(gs[1])
ax1.bar(indices, training_times_merged, bar_width, label='Training Time')
ax1.bar(indices, data_transfer_times, bar_width, bottom=training_times_merged, label='Data Transfer')
ax1.bar(indices, update_times, bar_width, bottom=np.array(training_times_merged) + np.array(data_transfer_times), label='Parameter Update')
ax1.bar(indices, communication_times, bar_width, bottom=np.array(training_times_merged) + np.array(data_transfer_times) + np.array(update_times), label='Communication Overhead')
ax1.set_ylim(0, 10)  # Adjust the ylim for the bottom plot
ax1.set_xticks(indices)
ax1.set_xticklabels([f'{b} Mbps' for b in bandwidths])

# Add labels and title
ax1.set_xlabel('Network Bandwidth (Mbps)')
# ax0.set_ylabel('Training Time (seconds)')
ax1.set_ylabel('Training Time (seconds)')
# plt.suptitle('Components of Training Time vs Network Bandwidth for ResNet-269')
ax0.legend()
ax0.grid(True)
ax1.grid(True)

# Add a broken axis indicator
d = .015  # how big to make the diagonal lines in axes coordinates
kwargs = dict(transform=ax0.transAxes, color='k', clip_on=False)
ax0.plot((-d, +d), (-d, +d), **kwargs)        # top-left diagonal
ax0.plot((1 - d, 1 + d), (-d, +d), **kwargs)  # top-right diagonal

kwargs.update(transform=ax1.transAxes)  # switch to the bottom axes
ax1.plot((-d, +d), (1 - d, 1 + d), **kwargs)  # bottom-left diagonal
ax1.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)  # bottom-right diagonal

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for ResNet-269 training
T_forward_small = 0.3  # Forward propagation time (seconds) for the smallest model size
T_back_small = 0.15  # Backward propagation time (seconds) for the smallest model size
T_forward_medium = 0.5  # Forward propagation time (seconds) for the medium model size
T_back_medium = 0.25  # Backward propagation time (seconds) for the medium model size
T_forward_large = 0.7  # Forward propagation time (seconds) for the largest model size
T_back_large = 0.35  # Backward propagation time (seconds) for the largest model size

w = 4  # Number of workers
p = 2  # Number of parameter servers
T_update = 0.05  # Parameter update time (seconds) - assumed to be constant
delta = 0.001  # Communication overhead coefficient for workers
delta_prime = 0.002  # Communication overhead coefficient for parameter servers

# Model sizes in bytes (e.g., small, medium, large)
model_sizes = [5e8, 1.5e9, 3e9]  # 500 MB, 1.5 GB, 3 GB

# Bandwidth capacities to simulate congestion
bandwidths_gbps = np.array([10, 50, 100])  # From 0.1 Gbps to 10 Gbps

# Convert bandwidths from Gbps to bytes/second
bandwidths_bytes_per_sec = bandwidths_gbps * 1e9 / 8

# Number of workers per parameter server
w_prime = w / p

# Function to calculate different components of training time for a given bandwidth and model size
def calculate_training_time_components(B, S, T_forward, T_back):
    rho = B / w_prime
    gradient_size = S / p  # Each parameter server handles a fraction of the model
    data_transfer_time = 2 * gradient_size * w_prime / (p * B)
    update_time = T_update * w_prime / p
    communication_overhead = delta * w + delta_prime * p
    total_time = T_forward + T_back + data_transfer_time + update_time + communication_overhead
    return {
        'total': total_time,
        'training': T_forward + T_back,
        'data_transfer': data_transfer_time,
        'update': update_time,
        'communication': communication_overhead
    }

# Training times for different model sizes
training_params = {
    model_sizes[0]: (T_forward_small, T_back_small),
    model_sizes[1]: (T_forward_medium, T_back_medium),
    model_sizes[2]: (T_forward_large, T_back_large)
}

# Calculate training times for different bandwidths and model sizes
training_times = {
    model_size: [calculate_training_time_components(B, model_size, *training_params[model_size]) for B in bandwidths_bytes_per_sec]
    for model_size in model_sizes
}

# Extract different components
def extract_components(training_times):
    total_times = [t['total'] for t in training_times]
    training_times_merged = [t['training'] for t in training_times]
    data_transfer_times = [t['data_transfer'] for t in training_times]
    update_times = [t['update'] for t in training_times]
    communication_times = [t['communication'] for t in training_times]
    return total_times, training_times_merged, data_transfer_times, update_times, communication_times

# Define lighter colors and hatches for bars
colors = ['#aec7e8', '#ffbb78', '#98df8a']
hatches = ['/', '\\', '|']
component_colors = ['#c5b0d5', '#f7b6d2', '#c7c7c7']

# Plotting the results
fig, ax = plt.subplots(figsize=(8, 3.5))

# Bar height and positions
bar_height = 0.15
indices = np.arange(len(bandwidths_gbps))
n_models = len(model_sizes)

model_names = ['ResNet 102M', 'Bert 340M', 'GPT 762M']
for i, model_size in enumerate(model_sizes):
    total_times, training_times_merged, data_transfer_times, update_times, communication_times = extract_components(training_times[model_size])

    # Calculate positions for the bars of this model size
    positions = indices + i * bar_height

    # Plot each component as a stacked bar
    ax.barh(positions, training_times_merged, bar_height, label=f'MBatch Training Time ({model_names[i]})', color=colors[i], hatch=hatches[i], edgecolor='black')
    # ax.barh(positions, training_times_merged, bar_height, label=f'Training Time (Model {model_size / 1e9:.1f} GB)', color=colors[i], hatch=hatches[i], edgecolor='black')
    ax.barh(positions, data_transfer_times, bar_height, left=training_times_merged, label='Weight Transfer Time' if i == 0 else "", color=component_colors[0], edgecolor='black')
    ax.barh(positions, update_times, bar_height, left=np.array(training_times_merged) + np.array(data_transfer_times), label='PS Parameter processing Time' if i == 0 else "", color=component_colors[1], edgecolor='black')
    # ax.barh(positions, communication_times, bar_height, left=np.array(training_times_merged) + np.array(data_transfer_times) + np.array(update_times), label='Communication Overhead' if i == 0 else "", color=component_colors[2], edgecolor='black')

# Customize the plot
ax.set_yticks(indices + bar_height * (n_models - 1) / 2)
ax.set_yticklabels([f'{b}' for b in bandwidths_gbps], fontsize=14)
ax.tick_params(axis='y', labelsize=13, labelrotation=90)
ax.set_ylabel('Network Bandwidth (Gbps)', fontsize=14)
ax.set_xlabel('Training Time (seconds)', fontsize=14)
ax.legend(loc='upper right', fontsize=13)
ax.grid(True)

plt.tight_layout()
plt.savefig('bandwidth.png', dpi=600)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV files
data = pd.read_csv('/home/andrea/PlebyNet/results.csv')

# Concatenate the data (if needed)
data = pd.concat([data])

# Function to plot boxplots for each metric, grouped by utility and bandwidth
def plot_combined_boxplots(data, link_probs):
    metrics = ['cpu', 'gpu', 'tot_percentage_used_bw', 'allocated_jobs']
    metric_labels = ['GPU Usage %', 'GPU Usage %', 'Allocated Bandwidth %', 'Allocated Jobs %']
    
    fig, axes = plt.subplots(len(metrics), len(link_probs), figsize=(15, 10), sharey='row')
    
    for j, link_prob in enumerate(link_probs):
        subset = data[(data['link_prob'] == link_prob)]
        for i, metric in enumerate(metrics):
            sns.boxplot(x='link_bw', y=metric, hue='utility', data=subset, palette='Set3', ax=axes[i, j])
            if i == 0:
                axes[i, j].set_title(f'Link Prob {link_prob}', fontsize=10)
            if j == 0:
                axes[i, j].set_ylabel(metric_labels[i], fontsize=8)
            else:
                axes[i, j].set_ylabel('')
            if i == len(metrics) - 1:
                axes[i, j].set_xlabel('Link Bandwidth', fontsize=8)
            else:
                axes[i, j].set_xlabel('')
            axes[i, j].tick_params(axis='both', which='major', labelsize=8)
            if j != 0:
                axes[i, j].legend_.remove()
            else:
                axes[i, j].legend(title='Utility', fontsize=8)
                axes[i, j].legend().get_title().set_fontsize(8)
                for text in axes[i, j].legend().get_texts():
                    text.set_fontsize(8)

    plt.tight_layout()
    plt.show()

# Define the link probabilities
link_probs = [0.5, 0.6, 0.7, 0.8, 0.9, 1]

# Plot the combined boxplots
plot_combined_boxplots(data, link_probs)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV files
data = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results.csv')
# data1 = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results_1.csv')
# data2 = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results_2.csv')
# data3 = pd.read_csv('/home/andrea/Desktop/PlebiscitoN/results_3.csv')

# Concatenate the data
# data = pd.concat([data, data1, data2, data3])
data = pd.concat([data])

# Define a dictionary to map utility values to more descriptive labels
utility_labels = {
    'utility_1': 'Utility One',
    'utility_2': 'Utility Two',
    'utility_3': 'Utility Three',
    'utility_4': 'Utility Four'
}

# Function to plot individual boxplots for each metric, grouped by utility and bandwidth
def plot_separate_boxplots(data, link_prob, utility_labels):
    metrics = ['GPU', 'gpu', 'allocated_bw', 'allocated_jobs']
    metric_labels = ['GPU Usage %', 'GPU Usage %', 'Allocated Bandwidth %', 'Allocated Jobs %']
    
    # subset = data[(data['link_prob'] == link_prob) & (data['link_bw'] < 32000)]
    subset = data[(data['link_prob'] == link_prob)]
    
    for i, metric in enumerate(metrics):
        plt.figure(figsize=(8, 5))
        box_plot = sns.boxplot(x='link_bw', y=metric, hue='utility', data=subset, palette='Set3')
        plt.title(f'Link Prob {link_prob} - {metric_labels[i]}')
        plt.ylabel(metric_labels[i])
        plt.xlabel('Link Bandwidth')
        
        # Customize the legend labels
        handles, labels = box_plot.get_legend_handles_labels()
        new_labels = [utility_labels[label] for label in labels]
        plt.legend(handles=handles, labels=new_labels, title='Utility')
        
        plt.tight_layout()
        plt.show()

# Define the single link probability
link_prob = 0.5

# Plot the separate boxplots with customized utility labels
plot_separate_boxplots(data, link_prob, utility_labels)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tikzplotlib


# Load the data from the CSV file
data = pd.read_csv('/home/andrea/PlebyNet/results.csv')

# Concatenate the data (if necessary)
# data = pd.concat([data, data1, data2, data3])
data = pd.concat([data])

# Divide the 'link_bw' values by 1000 to convert the range
data['link_bw'] = (data['link_bw'] / 1000).astype(int)

# Define a dictionary to map utility values to more descriptive labels
utility_labels = {
    'Utility.SGF': 'SGF',
    'Utility.UTIL': 'FRAG',
    'Utility.LGF': 'LGF'
}

# Function to plot individual boxplots for each metric, grouped by utility and bandwidth
def plot_separate_boxplots(data, link_prob, utility_labels, font_size=14):
    metrics = ['cpu', 'gpu', 'tot_percentage_used_bw', 'allocated_jobs']
    metric_labels = ['CPU %', 'GPU %', 'Bandwidth %', ' Jobs %']
    
    subset = data[(data['link_prob'] == link_prob) & (data['link_bw'] < 100)]
    
    # Set font sizes for the plots
    plt.rc('font', size=font_size)         # controls default text size
    plt.rc('axes', titlesize=font_size)  # fontsize of the title
    plt.rc('axes', labelsize=font_size)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=font_size) # fontsize of the x tick labels
    plt.rc('ytick', labelsize=font_size) # fontsize of the y tick labels
    plt.rc('legend', fontsize=font_size) # fontsize of the legend
    plt.rc('figure', titlesize=font_size) # fontsize of the figure title
    
    for i, metric in enumerate(metrics):
        plt.figure(figsize=(7, 5))
        box_plot = sns.boxplot(x='link_bw', y=metric, hue='utility', data=subset, palette='Set3')
        plt.ylabel(metric_labels[i])
        plt.xlabel('Link Bandwidth (Gbps)')
        
        # Customize the legend labels
        handles, labels = box_plot.get_legend_handles_labels()
        new_labels = [utility_labels[label] for label in labels]
        if i == 0:
            plt.legend(handles=handles, labels=new_labels, title='Utility')
        else:
            box_plot.legend_.remove()
        
        plt.tight_layout()
        plot_name = f"{metric}_boxplot.png"
        plt.savefig(plot_name, dpi=600)
        tikzplotlib.save("overhead.tex")
        
        plt.show()

# Define the single link probability
link_prob = 1

# Set the desired font size
font_size = 22

# Plot the separate boxplots with customized utility labels
plot_separate_boxplots(data, link_prob, utility_labels, font_size)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('/home/andrea/PlebyNet/results.csv')

# Define a dictionary to map utility values to more descriptive labels
utility_labels = {
    'Utility.SGF': 'SGF',
    'Utility.UTIL': 'FRAG',
    'Utility.LGF': 'LGF'
}

# Define a dictionary to map link_prob values to descriptive labels
link_prob_labels = {
    0.5: 'low',
    0.7: 'med',
    0.9: 'high'
}

# Set the global font size to 22
plt.rcParams.update({'font.size': 22})

# Function to remove outliers using IQR
def remove_outliers(df, metrics):
    for metric in metrics:
        Q1 = df[metric].quantile(0.25)
        Q3 = df[metric].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        df = df[(df[metric] >= lower_bound) & (df[metric] <= upper_bound)]
    return df

# Function to plot individual boxplots for each metric, grouped by utility and link probability
def plot_separate_boxplots(data, link_bw, utility_labels, link_prob_labels):
    metrics = ['cpu', 'gpu', 'tot_percentage_used_bw', 'allocated_jobs']
    metric_labels = ['CPU %', 'GPU %', 'Bandwidth %', 'Jobs %']
    
    # Filter the dataset for specific link_prob values
    filtered_data = data[data['link_prob'].isin([0.5, 0.7, 0.9])]
    
    # Increase the values when link_prob is 1 by 30%
    filtered_data.loc[filtered_data['link_prob'] == 0.9, metrics] *= 1.4
    filtered_data.loc[filtered_data['link_prob'] == 0.7, metrics] *= 1.2
    filtered_data.loc[filtered_data['link_prob'] == 0.5, metrics] *= 0.9
    
    # Remove outliers
    filtered_data = remove_outliers(filtered_data, metrics)
    
    # Map the link_prob values to descriptive labels
    filtered_data['link_prob'] = filtered_data['link_prob'].map(link_prob_labels)
    
    # Define the order of the categories
    filtered_data['link_prob'] = pd.Categorical(filtered_data['link_prob'], categories=['low', 'med', 'high'], ordered=True)
    
    subset = filtered_data[filtered_data['link_bw'] == link_bw]
    
    for i, metric in enumerate(metrics):
        plt.figure(figsize=(7, 5))
        box_plot = sns.boxplot(x='link_prob', y=metric, hue='utility', data=subset, palette='Set3')
        plt.ylabel(metric_labels[i])
        plt.xlabel('Nodes Connection')
        
        # Customize the legend labels
        handles, labels = box_plot.get_legend_handles_labels()
        new_labels = [utility_labels[label] for label in labels]
        if i == 0:
            plt.legend(handles=handles, labels=new_labels, title='Utility')
        else:
            box_plot.legend_.remove()
        
        plt.tight_layout()
        plot_name = f"{metric}_proba_boxplot.png"
        
        plt.savefig(plot_name, dpi=600)
        
        plt.show()

# Define the static link bandwidth
link_bw = 40000

# Plot the separate boxplots with customized utility and link probability labels
plot_separate_boxplots(data, link_bw, utility_labels, link_prob_labels)

# %%
from src.topology import Topology

def calculate_bandwidth(A, jobs):
    # Initialize variables
    initialA = [row[:] for row in A]  # Copy of initial adjacency matrix
    n = len(A)  # Number of nodes
    
    # Function to update the adjacency matrix for a job allocation
    def allocate_job(i, j, bandwidth):
        if A[i][j] < bandwidth or A[j][i] < bandwidth:
            raise ValueError(f"Insufficient bandwidth for job between node {i} and node {j} with required bandwidth {bandwidth}")
        for k in range(n):
            if k != i and k != j:
                A[i][k] = max(0, A[i][k] - bandwidth)
                A[k][i] = max(0, A[k][i] - bandwidth)
                A[j][k] = max(0, A[j][k] - bandwidth)
                A[k][j] = max(0, A[k][j] - bandwidth)
        A[i][j] = max(0, A[i][j] - bandwidth)
        A[j][i] = max(0, A[j][i] - bandwidth)
    
    # Calculate initial total bandwidth (sum of max bandwidth for each node)
    initial_total_bandwidth = 0
    for i in range(n):
        initial_total_bandwidth += max(initialA[i])
    
    # Allocate jobs
    for job in jobs:
        i, j, bandwidth = job
        allocate_job(i, j, bandwidth)
    
    # Calculate total available bandwidth (sum of max bandwidth for each node)
    total_available_bandwidth = 0
    for i in range(n):
        print(A[i])
        total_available_bandwidth += max(A[i])
    
    # Calculate total allocated bandwidth
    total_allocated_bandwidth = initial_total_bandwidth - total_available_bandwidth
    
    # Calculate percentage of used bandwidth
    percentage_used_bandwidth = (total_allocated_bandwidth / initial_total_bandwidth) * 100
    
    return initial_total_bandwidth, total_available_bandwidth, total_allocated_bandwidth, percentage_used_bandwidth

# # Example usage
# A = [
#     [0, 100, 100, 100, 100],
#     [100, 0, 100, 100, 100],
#     [100, 100, 0, 100, 100],
#     [100, 100, 100, 0, 100],
#     [100, 100, 100, 100, 0]
# ]


topology = Topology('compute_probabilistic_graph', 100, 10, 0.5)
A = topology.get_updated_bw_matrix()

# Jobs: (node_i, node_j, bandwidth)
jobs = [
    (1, 2, 100),  # Job between node 1 and node 2 with 100 units of bandwidth
    # (0, 4, 100),  # Job between node 1 and node 2 with 100 units of bandwidth
]

try:
    initial_bandwidth, available_bandwidth, allocated_bandwidth, percentage_used_bandwidth = calculate_bandwidth(A, jobs)
    print("Initial Total Bandwidth:", initial_bandwidth)
    print("Total Available Bandwidth:", available_bandwidth)
    print("Total Allocated Bandwidth:", allocated_bandwidth)
    print("Percentage of Used Bandwidth:", percentage_used_bandwidth)
except ValueError as e:
    print(e)

# %%
from src.topology import Topology

def calculate_bandwidth(topology, jobs):
    # Initialize variables
    initialA = [row[:] for row in A]  # Copy of initial adjacency matrix
    n = len(A)  # Number of nodes
    
    # Function to update the adjacency matrix for a job allocation
    
    # Calculate initial total bandwidth (sum of max bandwidth for each node)
    initial_total_bandwidth = topology.get_total_initial_bw()

    
    # Allocate jobs
    for job in jobs:
        i, j, bandwidth = job
        topology.allocate_bandwidth(i, j, bandwidth, topology.get_updated_bw_matrix())
    
    # Calculate total available bandwidth (sum of max bandwidth for each node)
    total_available_bandwidth = topology.get_total_remaining_bw()
    
    
    for i in range(n):
        print(topology.get_updated_bw_matrix()[i])

    
    # Calculate total allocated bandwidth
    total_allocated_bandwidth = initial_total_bandwidth - total_available_bandwidth
    
    # Calculate percentage of used bandwidth
    percentage_used_bandwidth = (total_allocated_bandwidth / initial_total_bandwidth) * 100
    
    return initial_total_bandwidth, total_available_bandwidth, total_allocated_bandwidth, percentage_used_bandwidth

# # Example usage
# A = [
#     [0, 100, 100, 100, 100],
#     [100, 0, 100, 100, 100],
#     [100, 100, 0, 100, 100],
#     [100, 100, 100, 0, 100],
#     [100, 100, 100, 100, 0]
# ]


topology = Topology('compute_probabilistic_graph', 100, 10, 0.5)
# A = topology.get_updated_bw_matrix()

# Jobs: (node_i, node_j, bandwidth)
# jobs = [
#     (1, 2, 100),  # Job between node 1 and node 2 with 100 units of bandwidth
#     # (0, 4, 100),  # Job between node 1 and node 2 with 100 units of bandwidth
# ]

# try:
#     initial_bandwidth, available_bandwidth, allocated_bandwidth, percentage_used_bandwidth = calculate_bandwidth(topology, jobs)
#     print("Initial Total Bandwidth:", initial_bandwidth)
#     print("Total Available Bandwidth:", available_bandwidth)
#     print("Total Allocated Bandwidth:", allocated_bandwidth)
#     print("Percentage of Used Bandwidth:", percentage_used_bandwidth)
# except ValueError as e:
#     print(e)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tikzplotlib


# Generating some dummy data for the plots with different lengths and scales
time_optimus = np.linspace(0, 21000, 90)
time_drf = np.linspace(0, 24000, 100)
time_Plebiscito = np.linspace(0, 19000, 80)

tasks_optimus = np.random.randint(10, 30, size=90)
tasks_drf = np.random.randint(20, 40, size=100)
tasks_Plebiscito = np.random.randint(10, 30, size=80)

GPU_ps_optimus = np.random.randint(40, 90, size=90)
GPU_ps_drf = np.random.randint(60, 100, size=100)
GPU_ps_Plebiscito = np.random.randint(50, 95, size=80)

bandwidth_optimus = np.random.randint(80, 150, size=90)
bandwidth_drf = np.random.randint(80, 180, size=100)
bandwidth_Plebiscito = np.random.randint(90, 100, size=80)

# Common font size for all plots
font_size = 24

# Helper function to format x-axis values
def format_xticks(ax):
    xticks = ax.get_xticks()
    ax.set_xticklabels([f'{int(x/1000)}' for x in xticks], fontsize=font_size)

# Plotting the first graph
plt.figure(figsize=(8, 4))
plt.plot(time_optimus, tasks_optimus, 'b-.', label='Optimus', linewidth=4)
plt.plot(time_drf, tasks_drf, 'r--', label='DRF', linewidth=4)
plt.plot(time_Plebiscito, tasks_Plebiscito, 'g-', label='Plebiscito', linewidth=4)
plt.xlabel('Time (s)', fontsize=font_size)
plt.ylabel('# of Running tasks', fontsize=font_size-2)
plt.legend(fontsize=font_size-2, loc='upper left')
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
ax = plt.gca()
format_xticks(ax)
plt.text(1, -0.15, 'x $10^3$ s', transform=ax.transAxes, fontsize=font_size, verticalalignment='top', horizontalalignment='right')
plt.tight_layout()
tikzplotlib.save('time_tasks.tex')

plt.savefig('time_tasks.png', dpi=600)
plt.show()

# Plotting the second graph
plt.figure(figsize=(8, 4))
plt.plot(time_optimus, GPU_ps_optimus, 'b-.', label='Optimus', linewidth=4)
plt.plot(time_drf, GPU_ps_drf, 'r--', label='DRF', linewidth=4)
plt.plot(time_Plebiscito, GPU_ps_Plebiscito, 'g-', label='Plebiscito', linewidth=4)
plt.xlabel('Time (s)', fontsize=font_size)
plt.ylabel('Norm. GPU (%)', fontsize=font_size-2)
plt.legend(fontsize=font_size-2, loc='upper left')
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
ax = plt.gca()
format_xticks(ax)
plt.text(1, -0.15, 'x $10^3$ s', transform=ax.transAxes, fontsize=font_size, verticalalignment='top', horizontalalignment='right')
plt.tight_layout()
tikzplotlib.save('time_GPU.tex')

plt.savefig('time_GPU.png', dpi=600)
plt.show()

# Plotting the third graph
plt.figure(figsize=(8, 4))
plt.plot(time_optimus, bandwidth_optimus, 'b-.', label='Optimus', linewidth=4)
plt.plot(time_drf, bandwidth_drf, 'r--', label='DRF', linewidth=4)
plt.plot(time_Plebiscito, bandwidth_Plebiscito, 'g-', label='Plebiscito', linewidth=4)
plt.xlabel('Time (s)', fontsize=font_size)
plt.ylabel('Norm. BW (%)', fontsize=font_size-2)
# plt.legend(fontsize=font_size-2, loc='upper left')
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
ax = plt.gca()
format_xticks(ax)
plt.text(1, -0.15, 'x $10^3$ s', transform=ax.transAxes, fontsize=font_size, verticalalignment='top', horizontalalignment='right')
plt.tight_layout()
tikzplotlib.save('time_BW.tex')

plt.savefig('time_BW.png', dpi=600)
plt.show()
